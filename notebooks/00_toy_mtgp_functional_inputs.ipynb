# %%
import sys
from pathlib import Path

# Project root (works whether the notebook is opened from root or from notebooks/)
ROOT = Path.cwd().resolve()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent

sys.path.insert(0, str(ROOT))
print("✅ Added project root to sys.path:", ROOT)
# Out:
# ✅ Added project root to sys.path: /home/razak-christophe/Documents/mtgp-functional-toy

# %%
from src.gp_model import MultiTaskfunctional
